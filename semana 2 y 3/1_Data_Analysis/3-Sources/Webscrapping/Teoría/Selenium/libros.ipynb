# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from splinter import Browser
import numpy as np

pd.set_option('max_colwidth', 800)

url = "https://es.wikipedia.org/wiki/Anexo:Campeones_de_la_NBA"
# response = requests.get(url, headers=headers)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import requests
from fake_useragent import UserAgent
import pandas as pd

ua = UserAgent()
user_agent = ua.random

options = webdriver.ChromeOptions()
options.add_argument(f'user-agent={user_agent}')

service = Service(executable_path='./chromedriver')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

        #Entrar a la web
driver.get("https://es.wikipedia.org/wiki/Anexo:Campeones_de_la_NBA")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\rafam\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: ./chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[3], line 17
#      15 service = Service(executable_path='./chromedriver')
#      16 options = webdriver.ChromeOptions()
# ---> 17 driver = webdriver.Chrome(service=service, options=options)
#      19         #Entrar a la web
# ...

# %%
nombre_equipos= []
campeonatos= []
anos_campeon= []

# %%
service = Service(executable_path=r'C:\Users\rafam\OneDrive\Documentos\GitHub\mi_copia_dsftmayo24semana1.1\semana 2 y 3\1_Data_Analysis\3-Sources\Webscrapping\Teoría\Selenium\chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get("https://es.wikipedia.org/wiki/Anexo:Campeones_de_la_NBA")

# %%
print(response)
# Out:
# <Response [200]>

# %%
html = response.content

# %%
soup = bs(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Anexo:Campeones de la NBA - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Anexo:Campeones de la NBA - Wikipedia, la enciclopedia libre</title>

# %%
soup.h1
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-namespace">Anexo</span><span class="mw-page-title-separator">:</span><span class="mw-page-title-main">Campeones de la NBA</span></h1>

# %%
soup.h1.get_text()
# Out:
# 'Anexo:Campeones de la NBA'

# %%
soup.a
# Out:
# <a class="mw-jump-link" href="#bodyContent">Ir al contenido</a>

# %%
soup.a['href']
# Out:
# '#bodyContent'

# %%
soup.find("a")
# Out:
# <a class="mw-jump-link" href="#bodyContent">Ir al contenido</a>

# %%
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Ir al contenido</a>,
#  <a accesskey="z" href="/wiki/Wikipedia:Portada" title="Visitar la página principal [z]"><span>Portada</span></a>,
#  <a href="/wiki/Portal:Comunidad" title="Acerca del proyecto, lo que puedes hacer, dónde encontrar información"><span>Portal de la comunidad</span></a>,
#  <a href="/wiki/Portal:Actualidad" title="Encuentra información de contexto sobre acontecimientos actuales"><span>Actualidad</span></a>,
#  <a accesskey="r" href="/wiki/Especial:CambiosRecientes" title="Lista de cambios recientes en la wiki [r]"><span>Cambios recientes</span></a>,
#  <a href="/wiki/Especial:P%C3%A1ginasNuevas"><span>Páginas nuevas</span></a>,
#  <a accesskey="x" href="/wiki/Especial:Aleatoria" title="Cargar una página al azar [x]"><span>Página aleatoria</span></a>,
#  <a href="/wiki/Ayuda:Contenidos" title="El lugar para aprender"><span>Ayuda</span></a>,
# ...

# %%
all_a = soup.find_all('a')
for a in all_a[:]:
    print(a.get_text())
# Out:
# Ir al contenido
# Portada
# Portal de la comunidad
# Actualidad
# Cambios recientes
# Páginas nuevas
# Página aleatoria
# Ayuda
# Donaciones
# Notificar un error
#
#
#
#
#
#
#
#
# Buscar
#
# Crear una cuenta
# Acceder
#  Crear una cuenta
#  Acceder
# más información
# Contribuciones
# Discusión
#
# Inicio
#
#
#
# 1
# Trofeos
#
#
#
#
# 1.1
# Trofeo Walter A. Brown
#
#
#
#
# 1.2
# Trofeo Larry O'Brien
#
#
#
#
# 2
# Campeones
#
#
#
#
# 2.1
# Campeones de la BAA
#
#
#
#
# 2.2
# Campeones de la NBA
#
#
#
#
# 2.3
# Campeonatos por Conferencia
#
#
#
#
# 3
# Número de campeonatos por equipo
#
#
#
#
# 4
# Véase también
#
#
#
#
# 5
# Referencias
#
#
#
#
# 6
# Enlaces externos
#
#
# العربية
# Azərbaycanca
# Беларуская
# Беларуская (тарашкевіца)
# English
# Suomi
# Français
# Magyar
# Հայերեն
# Bahasa Indonesia
# ქართული
# Latviešu
# Русский
# Simple English
# Tagalog
# Türkçe
# Українська
# Tiếng Việt
# 中文
# Editar enlaces
# Anexo
# Discusión
# Leer
# Editar
# Ver historial
# Leer
# Editar
# ...

# %%
ft= []
titulos= []


for elemento in soup.find_all("div", class_="ipc-metadata-list-summary-item__c"):
    full_text= elemento.find('a').get_text()
    title= full_text.split('. ', 1)[1]
    titulos.append(title)
    ft.append(full_text)
