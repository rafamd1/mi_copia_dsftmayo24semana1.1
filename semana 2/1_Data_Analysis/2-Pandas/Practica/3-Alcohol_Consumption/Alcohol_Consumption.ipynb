# %% [markdown]
# # Ex - GroupBy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
df= pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv", delimiter= ',')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks= pd.DataFrame(df)

# %%
drinks2= drinks.copy()

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# OJO:
#
# Hay null values en NA

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# Es una distribucion asimetrica. Media > Mediana. Hay unos pocos outliers que aumentan la media

# %%
drinks2.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %%
drinks2.groupby('continent')[['beer_servings']].mean()
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
# Europe

# %% [markdown]
# OTRA FORMA:

# %%
drinks2.groupby('continent')[['beer_servings']].mean().idxmax()
# Out:
# beer_servings    EU
# dtype: object

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %% [markdown]
# OJO:
#
# Los missing values pertencen a Norte y Centro America.
#
# Podemos rellenar esos valores y asignarlos a Norte y Centro America.

# %%
drinks['continent'].fillna("NCA", inplace= True)
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\1501418633.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   drinks['continent'].fillna("NCA", inplace= True)

# %%
drinks2['continent'].fillna("NCA", inplace= True)
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2902470544.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   drinks2['continent'].fillna("NCA", inplace= True)

# %%
drinks.groupby('continent')[['beer_servings']].mean()
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# NCA           145.434783
# OC             89.687500
# SA            175.083333

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks2.groupby('continent')[['wine_servings']].describe()
# Out:
#           wine_servings                                                   \
#                   count        mean        std  min   25%    50%     75%
# continent
# AF                 53.0   16.264151  38.846419  0.0   1.0    2.0   13.00
# AS                 44.0    9.068182  21.667034  0.0   0.0    1.0    8.00
# EU                 45.0  142.222222  97.421738  0.0  59.0  128.0  195.00
# OC                 16.0   35.625000  64.555790  0.0   1.0    8.5   23.25
# SA                 12.0   62.416667  88.620189  1.0   3.0   12.0   98.50
#
#
#              max
# continent
# AF         233.0
# AS         123.0
# EU         370.0
# OC         212.0
# SA         221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].mean()
# Out:
#            beer_servings  wine_servings  spirit_servings  \
# continent
# AF             61.471698      16.264151        16.339623
# AS             37.045455       9.068182        60.840909
# EU            193.777778     142.222222       132.555556
# OC             89.687500      35.625000        58.437500
# SA            175.083333      62.416667       114.750000
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# OTRA FORMA:

# %%
drinks2.groupby('continent')[drinks.columns[1:-1]].mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NCA           145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# NCA                            5.995652
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].median()
# Out:
#            beer_servings  wine_servings  spirit_servings  \
# continent
# AF                  32.0            2.0              3.0
# AS                  17.5            1.0             16.0
# EU                 219.0          128.0            122.0
# OC                  52.5            8.5             37.0
# SA                 162.5           12.0            108.5
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  wine_servings              ... spirit_servings         \
#              max         count        mean  ...             75%    max
# continent                                   ...
# AF         376.0          53.0   16.264151  ...           19.00  152.0
# AS         247.0          44.0    9.068182  ...           98.00  326.0
# EU         361.0          45.0  142.222222  ...          173.00  373.0
# ...

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].mean()
# Out:
#            beer_servings  wine_servings  spirit_servings  \
# continent
# AF             61.471698      16.264151        16.339623
# AS             37.045455       9.068182        60.840909
# EU            193.777778     142.222222       132.555556
# OC             89.687500      35.625000        58.437500
# SA            175.083333      62.416667       114.750000
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].min()
# Out:
#            beer_servings  wine_servings  spirit_servings  \
# continent
# AF                     0              0                0
# AS                     0              0                0
# EU                     0              0                0
# OC                     0              0                0
# SA                    93              1               25
#
#            total_litres_of_pure_alcohol
# continent
# AF                                  0.0
# AS                                  0.0
# EU                                  0.0
# OC                                  0.0
# SA                                  3.8

# %%
drinks2.groupby('continent')[['beer_servings', 'wine_servings', 'spirit_servings',  'total_litres_of_pure_alcohol']].max()
# Out:
#            beer_servings  wine_servings  spirit_servings  \
# continent
# AF                   376            233              152
# AS                   247            123              326
# EU                   361            370              373
# OC                   306            212              254
# SA                   333            221              302
#
#            total_litres_of_pure_alcohol
# continent
# AF                                  9.1
# AS                                 11.5
# EU                                 14.4
# OC                                 10.4
# SA                                  8.3

# %% [markdown]
# CORRECCION:
#
# ESTA MAL, ME PEDIAN SPIRIT SERVINGS

# %%
drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean])
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2778127805.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean])
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2778127805.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean])
# ...

# %%
drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean]).sort_values("mean", ascending = False)
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\896439545.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean]).sort_values("mean", ascending = False)
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\896439545.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   drinks.groupby('continent')['spirit_servings'].agg([min, max, np.mean]).sort_values("mean", ascending = False)
# ...

# %%
drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
                                 "spirit_servings": [np.min, np.max, np.mean]})
# Ordenar de forma descendente por la mediana de beer_servings
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2562866658.py:1: FutureWarning: The provided callable <function mean at 0x0000017CE240CE00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2562866658.py:1: FutureWarning: The provided callable <function median at 0x0000017CE24FF4C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
# ...

# %%
drinks3= drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
                                 "spirit_servings": [np.min, np.max, np.mean]})
# Ordenar de forma descendente por la mediana de beer_servings
# Out:
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2954820583.py:1: FutureWarning: The provided callable <function mean at 0x0000017CE240CE00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   drinks3= drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
# C:\Users\rafam\AppData\Local\Temp\ipykernel_37656\2954820583.py:1: FutureWarning: The provided callable <function median at 0x0000017CE24FF4C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   drinks3= drinks.groupby("continent").agg({"beer_servings": [np.mean, np.median],
# ...

# %%
drinks3[("beer_servings", "median")]
# Out:
# continent
# AF      32.0
# AS      17.5
# EU     219.0
# NCA    143.0
# OC      52.5
# SA     162.5
# Name: (beer_servings, median), dtype: float64

# %%
drinks3.sort_values(("beer_servings", "median"), ascending= False)
# Out:
#           beer_servings        spirit_servings
#                    mean median             min  max        mean
# continent
# EU           193.777778  219.0               0  373  132.555556
# SA           175.083333  162.5              25  302  114.750000
# NCA          145.434783  143.0              68  438  165.739130
# OC            89.687500   52.5               0  254   58.437500
# AF            61.471698   32.0               0  152   16.339623
# AS            37.045455   17.5               0  326   60.840909
