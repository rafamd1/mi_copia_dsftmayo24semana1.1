# %% [markdown]
# # Obtén datos de la API de Marvel
#
# ![imagen](https://cdn.hobbyconsolas.com/sites/navi.axelspringer.es/public/styles/hc_1440x810/public/media/image/2021/09/marvel-2460339.jpg?itok=cBnC1CBi)

# %% [markdown]
# Te tendrás que [registrar](https://developer.marvel.com/) y consultar la [documentación](https://developer.marvel.com/docs)

# %% [markdown]
# Queremos que consultes a la api para que te devuelva la info de los personajes de marvel que empiecen por la inicial de tu nombre. Deberemos guardarlos en un csv la información con la siguiente estructura
#
# ![imagen](./img/Captura_marvel.PNG)

# %% [markdown]
# Aquí te dejamos el código en python para poder empezar a hacer las llamadas, rellenando algunas variables como tus keys, parámetros de la llamada y la url (endpoint) a la que quieres acceder

# %%
import hashlib
import requests
import datetime
import pandas as pd

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)

# %%
def hash_params(timestamp,priv_key,pub_key):
     """ Marvel API requires server side API calls to include
     md5 hash of timestamp + public key + private key """

     hash_md5 = hashlib.md5()
     hash_md5.update(f'{timestamp}{priv_key}{pub_key}'.encode('utf-8'))
     hashed_params = hash_md5.hexdigest()

     return hashed_params

# %%
timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')

pub_key = '7682e65dd34d7bdb99c65a97cbc6af50'
priv_key = '45b130bbe775c53f1d6dafa5384464f6d2078206'

params = {'ts': timestamp, 
         'apikey': pub_key, 
         'hash': hash_params(timestamp,priv_key,pub_key),
         'limit': 100,
         'offset': 0
         };

url = 'http://gateway.marvel.com/v1/public/characters?nameStartsWith=R'

res = requests.get(url, params=params)

# %%
res
# Out:
# <Response [200]>

# %%
data= res.json()
data
# Out:
# {'code': 200,
#  'status': 'Ok',
#  'copyright': '© 2024 MARVEL',
#  'attributionText': 'Data provided by Marvel. © 2024 MARVEL',
#  'attributionHTML': '<a href="http://marvel.com">Data provided by Marvel. © 2024 MARVEL</a>',
#  'etag': 'c3dd200ab08409dfda8e77bc2e23edef0166afdc',
#  'data': {'offset': 0,
#   'limit': 100,
#   'total': 61,
#   'count': 61,
#   'results': [{'id': 1009430,
#     'name': 'Rachel Grey',
#     'description': '',
#     'modified': '2013-11-01T16:41:25-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/d/10/52741143108e7',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009430',
#     'comics': {'available': 98,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009430/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/8653',
#        'name': 'Excalibur (1988) #69'},
# ...

# %%
personaje= data["data"]["results"]
marvel = pd.DataFrame(personaje)
pedro = ['name', 'thumbnail']
marvel2 = marvel[pedro]
marvel2
# Out:
#                                  name  \
# 0                         Rachel Grey
# 1                     Radioactive Man
# 2                         Rafael Vega
# 3                                Rage
# 4                              Raider
# 5                             Randall
# 6                       Randall Flagg
# 7                              Random
# 8                             Rattler
# 9                            Ravenous
# 10                        Rawhide Kid
# 11                               Raza
# 12                             Reaper
# 13                            Reavers
# 14                 Reavers (Ultimate)
# 15                              Red 9
# 16                          Red Ghost
# 17               Red Ghost (Ultimate)
# 18    Red Guardian (Alexei Shostakov)
# 19                           Red Hulk
# 20                     Red Hulk (HAS)
# 21                       Red She-Hulk
# 22                          Red Shift
# ...

# %%
marvel2.to_csv('peliculas2.csv', index=False)

# %%
Your public key
7682e65dd34d7bdb99c65a97cbc6af50
Your private key
45b130bbe775c53f1d6dafa5384464f6d2078206
# Out:
#   Cell In[8], line 2
#     7682e65dd34d7bdb99c65a97cbc6af50
#           ^
# SyntaxError: invalid decimal literal
